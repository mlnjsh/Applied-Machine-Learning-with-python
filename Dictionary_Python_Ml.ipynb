# %% [markdown]
# # Dictionary : Is like a Hash Table

# %% [markdown]
# Hash Table is studied in data structures ( CS/ IT- Undergraduate). Python dictionary is an ***unordered collection*** ( No indexing is possible) of items. While other compound data types have only value as an element, a dictionary has a key: value pair.
#
# ####  Dict =  {  Key :  'Value' }  -----> We put curly braces to store ( Here key is integer}
# ####  Dict =  {  'Key' :  'Value' } ------> Here key is string
# ## Dict could have mixed keys
#
# ## Dictonary can be thought of as a table containing Key and its corrosponding value with colon(:) in between key and value

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Milan Joshi\\Desktop\\table.png')

# %% [markdown]
# # Dict Creation

# %%
#empty dictionary
my_dict = {}

#dictionary with integer keys  
my_dict = {1: 'abc', 2: 'xyz'}   # 1 is the key and 'abc' is its value also 2 is the key 'xyz is the value'


# For key 1 we store 'abc' and for key 2 we store 'xyz' by the way my_dict create a table with key and value

print(my_dict)

#dictionary with mixed keys

my_dict = {'name': 'Milan', 1: ['abc', 'xyz']}

print(my_dict)


#create empty dictionary using dict()
my_dict = dict()

my_dict = dict([(1, 'abc'), (2, 'xyz')]) #create a dict with list of tuples
print(my_dict)
# Out:
# {1: 'abc', 2: 'xyz'}
# {'name': 'Milan', 1: ['abc', 'xyz']}
# {1: 'abc', 2: 'xyz'}

# %%
Image(filename='C:\\Users\\Milan Joshi\\Desktop\\dict.png')

# %%
Image(filename='C:\\Users\\Milan Joshi\\Desktop\\dict.png')

# %% [markdown]
# # Dict Access

# %%
my_dict = {'name': 'Milan', 'age': 32, 'address': 'Shirpur'}  # key 1 = k1 , key2 = k2 , key3 = k3

#get name
print(my_dict['name'])  ### my_dict['key']
# Out:
# Milan

# %%
#if key is not present it gives KeyError
print(my_dict['degree'])  # There is no key as degree  in my_dict above
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-a24c24b0fec2> in <module>()
#       1 #if key is not present it gives KeyError
# ----> 2 print(my_dict['degree'])  # There is no key as degree  in my_dict above
#
# KeyError: 'degree'

# %%
#another way of accessing key
print(my_dict.get('address'))   # .get is a function in dictonary
# Out:
# Shirpur

# %%
#if key is not present it will give None using get method
print(my_dict.get('degree'))
# Out:
# None

# %% [markdown]
# # Dict Add or Modify  Elements

# %%
my_dict = {'name': 'Milan', 'age': 32, 'address': 'Shirpur'}

#update name 
my_dict['name'] = 'joshi'  # Update a value given key

print(my_dict)
# Out:
# {'name': 'joshi', 'age': 32, 'address': 'Shirpur'}

# %%
#add new key
my_dict['degree'] = 'Ph.D(Math)'

print(my_dict)
# Out:
# {'name': 'joshi', 'age': 32, 'address': 'Shirpur', 'degree': 'Ph.D(Math)'}

# %% [markdown]
# # Dict Delete or Remove Element

# %%
#create a dictionary
my_dict = {'name': 'Milan', 'age': 32, 'address': 'Shirpur'}

#remove a particular item..Return the value but remove it
print(my_dict.pop('age'))

print(my_dict)
# Out:
# 32
# {'name': 'Milan', 'address': 'Shirpur'}

# %%
my_dict = {'name': 'Milan', 'age': 32, 'address': 'Shirpur'}

#remove an arbitarty key
my_dict.popitem()

print(my_dict)
# Out:
# {'name': 'Milan', 'age': 32}

# %%
squares = {2: 4, 3: 9, 4: 16, 5: 25}

#delete particular key
del squares[2]

print(squares)
# Out:
# {3: 9, 4: 16, 5: 25}

# %%
#remove all items
squares.clear()

print(squares)
# Out:
# {}

# %%
squares = {2: 4, 3: 9, 4: 16, 5: 25}

#delete dictionary itself
del squares

print(squares) #NameError because dict is deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6fac7747ecad> in <module>()
#       4 del squares
#       5
# ----> 6 print(squares) #NameError because dict is deleted
#
# NameError: name 'squares' is not defined

# %% [markdown]
# # Dictionary Methods

# %%
squares = {2: 4, 3: 9, 4: 16, 5: 25}

my_dict = squares.copy()
print(my_dict)
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25}

# %%
#fromkeys[seq[, v]] -> Return a new dictionary with keys from seq and value equal to v (defaults to None).
subjects = {}.fromkeys(['Math', 'English', 'Hindi'], 0) 
print(subjects)
# Out:
# {'Math': 0, 'English': 0, 'Hindi': 0}

# %%
subjects = {2:4, 3:9, 4:16, 5:25}
print(subjects.items()) #return a new view of the dictionary items (key, value) List of tuples [(K1,V1),(K2,V2)...,(K4,V4)]
# Out:
# dict_items([(2, 4), (3, 9), (4, 16), (5, 25)])

# %%
subjects = {2:4, 3:9, 4:16, 5:25}
print(subjects.keys()) #return a new view of the dictionary keys
# Out:
# dict_keys([2, 3, 4, 5])

# %%
subjects = {2:4, 3:9, 4:16, 5:25}
print(subjects.values()) #return a new view of the dictionary values
# Out:
# dict_values([4, 9, 16, 25])

# %%
#get list of all available methods and attributes of dictionary
d = {}
print(dir(d))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %% [markdown]
# # Dict Comprehension

# %%
#Dict comprehensions are just like list comprehensions but for dictionaries

d = {'a': 1, 'b': 2, 'c': 3}
for i in d.items():
    print(i)
# Out:
# ('a', 1)
# ('b', 2)
# ('c', 3)

# %%
#Creating a new dictionary with only pairs where the value is larger than 2
d = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
new_dict = {k:v for k, v in d.items() if v > 1}
print(new_dict)
# Out:
# {'b': 2, 'c': 3, 'd': 4}

# %%
#We can also perform operations on the key value pairs
d = {'a':1,'b':2,'c':3,'d':4,'e':5}
d = {k + 'c':v * 2 for k, v in d.items() if v > 2}  # k+'c' concatinate c with the keys whose values is
# greater than 2 and multiply vlaue then by 2

print(d)
# Out:
# {'cc': 6, 'dc': 8, 'ec': 10}
